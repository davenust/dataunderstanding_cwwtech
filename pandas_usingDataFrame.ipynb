# %%
# This is a tutorial on using Pandas with DataFrame
# all data are not changing because they are immutable operations

# this is importing all the necessary libaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Waiting for the activating process in Python Environment

# %%
# The dataset to use:
# we can consider dataframe as a combination of series
df = pd.DataFrame({
	'Population': [35.467, 63.951, 80.94, 60.665, 127.061, 64.511, 318.523],
	'GDP': [
		1785387,
		2833687,
		3874437,
		2167744,
		4602367,
		2950039,
		17348075
		],
	'Surface': [
		9984678,
		640679,
		357114,
		301336,
		377930,
		242495,
		9525067
		],
	'HDI': [
		0.913,
		0.888,
		0.916,
		0.873,
		0.891,
		0.907,
		0.915
		],
	'Continent': [
		'America',
		'Europe',
		'Europe',
		'Europe',
		'Asia',
		'Europe',
		'America'
		]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])
df
# Out:
#    Population       GDP Surface Area    HDI Continent
# 0      35.467   1785387          NaN  0.913   America
# 1      63.951   2833687          NaN  0.888    Europe
# 2      80.940   3874437          NaN  0.916    Europe
# 3      60.665   2167744          NaN  0.873    Europe
# 4     127.061   4602367          NaN  0.891      Asia
# 5      64.511   2950039          NaN  0.907    Europe
# 6     318.523  17348075          NaN  0.915   America

# %%
# assigning an index (Countries) into the dataframe
df.index =[
    'Canada',
    'France',
    'England',
    'Spain',
    'Japan',
    'Russia',
    'United States'
]
df
# Out:
#                Population       GDP Surface Area    HDI Continent
# Canada             35.467   1785387          NaN  0.913   America
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# this is to check the info about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  0 non-null      object
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 336.0+ bytes

# %%
# checking the size of the dataset
df.size
# Out:
# 35

# %%
#checking the shape
df.shape
# Out:
# (7, 5)

# %%
#checking the columns
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
#checking the index
df.index
# Out:
# Index(['Canada', 'France', 'England', 'Spain', 'Japan', 'Russia',
#        'United States'],
#       dtype='object')

# %%
# describe give the aggregate as count, mean, std, min, %s and Max
df.describe()
# Out:
#        Population           GDP       HDI
# count    7.000000  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  0.900429
# std     97.249970  5.494020e+06  0.016592
# min     35.467000  1.785387e+06  0.873000
# 25%     62.308000  2.500716e+06  0.889500
# 50%     64.511000  2.950039e+06  0.907000
# 75%    104.000500  4.238402e+06  0.914000
# max    318.523000  1.734808e+07  0.916000

# %%
# INDEXING, SELECTION AND SLICING
# This talks about how to be selecting data from the series (in this case the dataset)

# we print out dataframe out given it as df
df
# Out:
#                Population       GDP Surface Area    HDI Continent
# Canada             35.467   1785387          NaN  0.913   America
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# the .loc attribute will allow to get the data for each row, providing the index, 
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area        NaN
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
# while .iloc will let you select by sequential position
df.iloc[-2]
# Out:
# Population       64.511
# GDP             2950039
# Surface Area        NaN
# HDI               0.907
# Continent        Europe
# Name: Russia, dtype: object

# %%
# df[] is giving the extire column stated inside the lock (e.g, list of columns we have)
df['Population']
# Out:
# Canada            35.467
# France            63.951
# England           80.940
# Spain             60.665
# Japan            127.061
# Russia            64.511
# United States    318.523
# Name: Population, dtype: float64

# %%
df.loc['France' : 'Russia', 'Population']
# Out:
# France      63.951
# England     80.940
# Spain       60.665
# Japan      127.061
# Russia      64.511
# Name: Population, dtype: float64

# %%
df.loc['France' : 'Russia', ['Population', 'HDI']]
# Out:
#          Population    HDI
# France       63.951  0.888
# England      80.940  0.916
# Spain        60.665  0.873
# Japan       127.061  0.891
# Russia       64.511  0.907

# %%
df.loc['France' : 'Russia']
# Out:
#          Population      GDP Surface Area    HDI Continent
# France       63.951  2833687          NaN  0.888    Europe
# England      80.940  3874437          NaN  0.916    Europe
# Spain        60.665  2167744          NaN  0.873    Europe
# Japan       127.061  4602367          NaN  0.891      Asia
# Russia       64.511  2950039          NaN  0.907    Europe

# %%
# CONDITIONAL SELECTION (Boolean Array)
# a way to filter data

df
# Out:
#                Population       GDP Surface Area    HDI Continent
# Canada             35.467   1785387          NaN  0.913   America
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# to filter a population > 70
df['Population'] > 70
# Out:
# Canada           False
# France           False
# England           True
# Spain            False
# Japan             True
# Russia           False
# United States     True
# Name: Population, dtype: bool

# %%
# using .loc works at the index level to populate all the dataset from the query given

df.loc[df['Population'] > 70]
# Out:
#                Population       GDP Surface Area    HDI Continent
# England            80.940   3874437          NaN  0.916    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# United States     318.523  17348075          NaN  0.915   America

# %%
# here we are defining the column we want us to give with .loc
df.loc[df['Population'] > 70, ['Population', 'GDP']]
# Out:
#                Population       GDP
# England            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %%
# Dropping stuff
# opposed to the concept of selection, we have "dropping", 
# instead of pointing out which values you'd like to select you could point which ones you'd like to drop:
df.drop('Canada')
# Out:
#                Population       GDP Surface Area    HDI Continent
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
df.drop(['Canada' ,'France'])
# Out:
#                Population       GDP Surface Area    HDI Continent
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# using .drop() to drop columns
df.drop(columns=['Population'])
# Out:
#                     GDP Surface Area    HDI Continent
# Canada          1785387          NaN  0.913   America
# France          2833687          NaN  0.888    Europe
# England         3874437          NaN  0.916    Europe
# Spain           2167744          NaN  0.873    Europe
# Japan           4602367          NaN  0.891      Asia
# Russia          2950039          NaN  0.907    Europe
# United States  17348075          NaN  0.915   America

# %%
# OPERATIONS
# operations with series work at a column level, broadcasting down the rows (which can be counter intuitive)
df[['Population', 'HDI', 'GDP']]
# Out:
#                Population    HDI       GDP
# Canada             35.467  0.913   1785387
# France             63.951  0.888   2833687
# England            80.940  0.916   3874437
# Spain              60.665  0.873   2167744
# Japan             127.061  0.891   4602367
# Russia             64.511  0.907   2950039
# United States     318.523  0.915  17348075

# %%
df[['Population', 'HDI', 'GDP']] / 100
# Out:
#                Population      HDI        GDP
# Canada            0.35467  0.00913   17853.87
# France            0.63951  0.00888   28336.87
# England           0.80940  0.00916   38744.37
# Spain             0.60665  0.00873   21677.44
# Japan             1.27061  0.00891   46023.67
# Russia            0.64511  0.00907   29500.39
# United States     3.18523  0.00915  173480.75

# %%
df[['GDP','HDI']]
# Out:
#                     GDP    HDI
# Canada          1785387  0.913
# France          2833687  0.888
# England         3874437  0.916
# Spain           2167744  0.873
# Japan           4602367  0.891
# Russia          2950039  0.907
# United States  17348075  0.915

# %%
# creating a variable to add value to the column stated in the index
crisis = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']] + crisis
# Out:
#                       GDP    HDI
# Canada           785387.0  0.613
# France          1833687.0  0.588
# England         2874437.0  0.616
# Spain           1167744.0  0.573
# Japan           3602367.0  0.591
# Russia          1950039.0  0.607
# United States  16348075.0  0.615

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent
# Canada             35.467   1785387          NaN  0.913   America
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# all data are not changing because they are immutable operations
# Modifying Dataframes
# all data are immutable, there are ways to change it.
# it is simple and intuitive, you can add columns, or replace values for columns without issues;

df
# Out:
#                Population       GDP Surface Area    HDI Continent
# Canada             35.467   1785387          NaN  0.913   America
# France             63.951   2833687          NaN  0.888    Europe
# England            80.940   3874437          NaN  0.916    Europe
# Spain              60.665   2167744          NaN  0.873    Europe
# Japan             127.061   4602367          NaN  0.891      Asia
# Russia             64.511   2950039          NaN  0.907    Europe
# United States     318.523  17348075          NaN  0.915   America

# %%
# adding a new Column to existing table
langs = pd.Series(
	['French', 'English', 'English', 'Japanese', 'Russian', 'Spanish', 'English'],
	index=['France', 'England', 'Canada', 'Japan', 'Russia', 'Spain', 'United States'],
	name='Language'
)
df['Language'] = langs
langs
# Out:
# France             French
# England           English
# Canada            English
# Japan            Japanese
# Russia            Russian
# Spain             Spanish
# United States     English
# Name: Language, dtype: object

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent  Language
# Canada             35.467   1785387          NaN  0.913   America   English
# France             63.951   2833687          NaN  0.888    Europe    French
# England            80.940   3874437          NaN  0.916    Europe   English
# Spain              60.665   2167744          NaN  0.873    Europe   Spanish
# Japan             127.061   4602367          NaN  0.891      Asia  Japanese
# Russia             64.511   2950039          NaN  0.907    Europe   Russian
# United States     318.523  17348075          NaN  0.915   America   English

# %%
# Replacing values per column
df['Language'] = 'English'
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English

# %%
df['Language'] = 'English'
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English

# %%
# renaming column with df.rename()
df.rename(
columns={
	'HDI': 'Human Development Index',
	'GDP': 'Gross Domestic Product'
    },
index={'United States': 'US'})
# Out:
#          Population  Gross Domestic Product Surface Area  \
# Canada       35.467                 1785387          NaN
# France       63.951                 2833687          NaN
# England      80.940                 3874437          NaN
# Spain        60.665                 2167744          NaN
# Japan       127.061                 4602367          NaN
# Russia       64.511                 2950039          NaN
# US          318.523                17348075          NaN
#
#          Human Development Index Continent Language
# Canada                     0.913   America  English
# France                     0.888    Europe  English
# England                    0.916    Europe  English
# Spain                      0.873    Europe  English
# Japan                      0.891      Asia  English
# Russia                     0.907    Europe  English
# US                         0.915   America  English

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English

# %%
# Creating columns from other Columns
df[['Population', 'GDP']]
# Out:
#                Population       GDP
# Canada             35.467   1785387
# France             63.951   2833687
# England            80.940   3874437
# Spain              60.665   2167744
# Japan             127.061   4602367
# Russia             64.511   2950039
# United States     318.523  17348075

# %%
df['GDP per Capita'] = df['Population']/df['GDP']
df['GDP per Capita']
# Out:
# Canada           0.000020
# France           0.000023
# England          0.000021
# Spain            0.000028
# Japan            0.000028
# Russia           0.000022
# United States    0.000018
# Name: GDP per Capita, dtype: float64

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language  \
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English
#
#                GDP per Capita
# Canada               0.000020
# France               0.000023
# England              0.000021
# Spain                0.000028
# Japan                0.000028
# Russia               0.000022
# United States        0.000018

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language  \
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English
#
#                GDP per Capita
# Canada               0.000020
# France               0.000023
# England              0.000021
# Spain                0.000028
# Japan                0.000028
# Russia               0.000022
# United States        0.000018

# %%
# Statistical Info
# .describe(), population = df['Population'], population.sum(), 
#population.sum() / len(population), population.mean(), 
#population.std(), population.median(), population.desccribe(), population.quanatile(.25)

df.describe()
# Out:
#        Population           GDP       HDI  GDP per Capita  HDI per Population
# count    7.000000  7.000000e+00  7.000000        7.000000            7.000000
# mean   107.302571  5.080248e+06  0.900429        0.000023           97.063260
# std     97.249970  5.494020e+06  0.016592        0.000004           89.264515
# min     35.467000  1.785387e+06  0.873000        0.000018           32.381371
# 25%     62.308000  2.500716e+06  0.889500        0.000020           54.874516
# 50%     64.511000  2.950039e+06  0.907000        0.000022           58.511477
# 75%    104.000500  4.238402e+06  0.914000        0.000025           93.676196
# max    318.523000  1.734808e+07  0.916000        0.000028          291.448545

# %%
population = df['Population']
population
# Out:
# Canada            35.467
# France            63.951
# England           80.940
# Spain             60.665
# Japan            127.061
# Russia            64.511
# United States    318.523
# Name: Population, dtype: float64

# %%
population.mean()
# Out:
# 107.30257142857144

# %%
population.sum() / len(population)
# Out:
# 107.30257142857144

# %%
df
# Out:
#                Population       GDP Surface Area    HDI Continent Language  \
# Canada             35.467   1785387          NaN  0.913   America  English
# France             63.951   2833687          NaN  0.888    Europe  English
# England            80.940   3874437          NaN  0.916    Europe  English
# Spain              60.665   2167744          NaN  0.873    Europe  English
# Japan             127.061   4602367          NaN  0.891      Asia  English
# Russia             64.511   2950039          NaN  0.907    Europe  English
# United States     318.523  17348075          NaN  0.915   America  English
#
#                GDP per Capita  HDI per Population
# Canada               0.000020           32.381371
# France               0.000023           56.788488
# England              0.000021           74.141040
# Spain                0.000028           52.960545
# Japan                0.000028          113.211351
# Russia               0.000022           58.511477
# United States        0.000018          291.448545
