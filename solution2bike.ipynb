# %%
# Loading of all the necessaries libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

Bike = pd.read_csv

# %%
Bike = pd.read_csv(r'C:/Users/hp/Desktop/dataunderstanding_cww/dataunderstanding_cwwtech/Sales.csv')
Bike
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
Bike.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
Bike.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Day'}>,
#         <Axes: title={'center': 'Year'}>,
#         <Axes: title={'center': 'Customer_Age'}>],
#        [<Axes: title={'center': 'Order_Quantity'}>,
#         <Axes: title={'center': 'Unit_Cost'}>,
#         <Axes: title={'center': 'Unit_Price'}>],
#        [<Axes: title={'center': 'Profit'}>,
#         <Axes: title={'center': 'Cost'}>,
#         <Axes: title={'center': 'Revenue'}>]], dtype=object)

# %%
Bike.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
# Format the date with .to_date() function
Bike['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 113036 entries, 0 to 113035
# Series name: Date
# Non-Null Count   Dtype
# --------------   -----
# 113036 non-null  object
# dtypes: object(1)
# memory usage: 883.2+ KB

# %%
Bike['Date'] = pd.to_datetime(Bike['Date'].head())
Bike['Date']
# Out:
# 0        2013-11-26
# 1        2015-11-26
# 2        2014-03-23
# 3        2016-03-23
# 4        2014-05-15
#             ...
# 113031          NaT
# 113032          NaT
# 113033          NaT
# 113034          NaT
# 113035          NaT
# Name: Date, Length: 113036, dtype: datetime64[ns]

# %%
Bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              5 non-null       datetime64[ns]
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
Bike.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0 2013-11-26   26  November  2013            19     Youth (<25)
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
# Numerical Analysis
Bike.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
# Year Sales with Visualization
Bike['Year'].value_counts()
# Out:
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: Year, dtype: int64

# %%
Bike['Year'].sum()
# Out:
# 227699915

# %%
# visualization for year with highest sales

Bike['Year'].value_counts().plot(kind="bar",figsize=(16,6))
# Out:
# <Axes: >

# %%
# Month Sales with Visualization from 2011 - 2014
Bike['Month'].value_counts()
# Out:
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: Month, dtype: int64

# %%
# Visualization for the month with the years sales (2011 - 2014)
Bike['Month'].value_counts().plot(kind='bar', figsize=(16,6))
# Out:
# <Axes: >

# %%
Bike
# Out:
#              Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26  November  2013            19     Youth (<25)
# 1      2015-11-26   26  November  2015            19     Youth (<25)
# 2      2014-03-23   23     March  2014            49  Adults (35-64)
# 3      2016-03-23   23     March  2016            49  Adults (35-64)
# 4      2014-05-15   15       May  2014            47  Adults (35-64)
# ...           ...  ...       ...   ...           ...             ...
# 113031        NaT   12     April  2016            41  Adults (35-64)
# 113032        NaT    2     April  2014            18     Youth (<25)
# 113033        NaT    2     April  2016            18     Youth (<25)
# 113034        NaT    4     March  2014            37  Adults (35-64)
# 113035        NaT    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
# increase the revenue sales by 100$
Bike['Revenue'] + 100
# Out:
# 0         1050
# 1         1050
# 2         2501
# 3         2188
# 4          518
#           ...
# 113031     284
# 113032    1283
# 113033    1283
# 113034    1360
# 113035    1307
# Name: Revenue, Length: 113036, dtype: int64

# %%
Bike['Revenue'].value_counts()
# Out:
# 35      824
# 20      783
# 10      763
# 5       754
# 30      752
#        ...
# 1732      1
# 1117      1
# 1418      1
# 2148      1
# 1428      1
# Name: Revenue, Length: 1876, dtype: int64

# %%
Bike['Profit'].sum()
# Out:
# 32221100

# %%
Bike['Profit'] > 1000
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 113031    False
# 113032    False
# 113033    False
# 113034    False
# 113035    False
# Name: Profit, Length: 113036, dtype: bool

# %%
# Age Group Sales
Bike['Age_Group'].value_counts()
# Out:
# Adults (35-64)          55824
# Young Adults (25-34)    38654
# Youth (<25)             17828
# Seniors (64+)             730
# Name: Age_Group, dtype: int64

# %%
# Age group with the highest sales with Pie chart
Bike['Age_Group'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Age_Group'>

# %%
# Gender with highest sales

Bike['Customer_Gender'].value_counts()
# Out:
# M    58312
# F    54724
# Name: Customer_Gender, dtype: int64

# %%
# Gender group with the highest sales with Pie chart
Bike['Customer_Gender'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='Customer_Gender'>

# %%
Bike['Order_Quantity'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 113036 entries, 0 to 113035
# Series name: Order_Quantity
# Non-Null Count   Dtype
# --------------   -----
# 113036 non-null  int64
# dtypes: int64(1)
# memory usage: 883.2 KB

# %%
Bike['Order_Quantity'].mean()
# Out:
# 11.901659648253654

# %%
Bike['Order_Quantity'].median()
# Out:
# 10.0

# %%
# Visualization for Order of Quantity
Bike['Order_Quantity'].plot(kind='box', vert=False, figsize=(12,6))
# Out:
# <Axes: >

# %%
# Sales according to Country
Bike['Country'].value_counts()
# Out:
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: Country, dtype: int64

# %%
# Visualization for Country
Bike['Country'].value_counts().plot(kind='bar', figsize=(12,6))
plt.title('Country with Highest Order')
# Out:
# Text(0.5, 1.0, 'Country with Highest Order')

# %%
Bike['Product'].value_counts()
# Out:
# Water Bottle - 30 oz.      10794
# Patch Kit/8 Patches        10416
# Mountain Tire Tube          6816
# AWC Logo Cap                4358
# Sport-100 Helmet, Red       4220
#                            ...
# Mountain-100 Silver, 48       58
# Mountain-100 Silver, 42       54
# Mountain-500 Silver, 48       40
# Road-650 Red, 52              32
# Mountain-500 Black, 52        22
# Name: Product, Length: 130, dtype: int64

# %%
# Product with the most sales
Most_Sales = Bike.loc[:,'Product'].unique()

# %%
Bike.loc[:,'Product'].value_counts().head(10).plot(kind='bar', figsize=(12,6))
# Out:
# <Axes: >

# %%
# Order_quantity and Profit
Bike.plot(kind='box', x='Order_Quantity', y='Profit', figsize=(12,4))
plt.title('Relationship between Order Quantity and Price')
# Out:
# Text(0.5, 1.0, 'Relationship between Order Quantity and Price')

# %%
# Relationship between country and unit profit
Bike.plot(kind='box', x='Country', y='Profit', figsize=(12,4), vert=False)
plt.title('Relationship between Order Country and Price')
# Out:
# Text(0.5, 1.0, 'Relationship between Order Country and Price')

# %%
# customer age to country
Bike[["Customer_Age","Country"]].boxplot(by='Country',figsize=(10,6))

# %%
# Sales in each state of United State
Bike.loc[Bike['Country'] == 'France', 'State'].value_counts()
# Out:
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: State, dtype: int64

# %%
# Virtualization for it
Bike.loc[Bike['Country'] == 'France', 'State'].value_counts().plot(kind='bar', figsize=(12,4))
plt.title('State With Highest Orders')
plt.xlabel('States')
plt.ylabel('Total Counts')
plt.legend()

# %%
# Sales per Product Category
Bike['Product_Category'].value_counts()
# Out:
# Accessories    70120
# Bikes          25982
# Clothing       16934
# Name: Product_Category, dtype: int64

# %%
# Visualization for Product Category
Bike['Product_Category'].value_counts().plot(kind='pie', figsize=(12,4), autopct='%1.1f%%')
Bike['Product_Category'].value_counts().plot(kind='')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# Sales per Product Category
Bike['Sub_Category'].value_counts()
# Out:
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: Sub_Category, dtype: int64

# %%
# Virtualization for Sub_Category
Bike['Sub_Category'].value_counts().plot(kind='bar', figsize=(12,4))
plt.title('Sub Category Category')
plt.xlabel('Items on Sub_Category')
plt.ylabel('Value Count of Items')
plt.legend
# Out:
# <function matplotlib.pyplot.legend(*args, **kwargs)>

# %%
# Top 5 Best Revenues
Bike.sort_values(['Revenue'], ascending=False).head(10)
# Out:
#               Date  Day      Month  Year  Customer_Age             Age_Group  \
# 112073  2015-07-24   24       July  2015            52        Adults (35-64)
# 112072  2013-07-24   24       July  2013            52        Adults (35-64)
# 71129   2011-07-08    8       July  2011            22           Youth (<25)
# 70307   2011-04-30   30      April  2011            44        Adults (35-64)
# 70601   2011-09-30   30  September  2011            19           Youth (<25)
# 70699   2011-07-17   17       July  2011            30  Young Adults (25-34)
# 70597   2011-05-12   12        May  2011            19           Youth (<25)
# 70745   2011-02-11   11   February  2011            39        Adults (35-64)
# 59919   2011-03-20   20      March  2011            29  Young Adults (25-34)
# 68671   2011-07-05    5       July  2011            26  Young Adults (25-34)
#
#        Customer_Gender    Country             State Product_Category  \
# ...

# %%
Bike.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Bike.describe()
#
# NameError: name 'Bike' is not defined
